# %%
from sklearn.datasets import fetch_california_housing

House = fetch_california_housing()

# %%
#print(House.DESCR)

# %%
#print(House.data.shape)
#print(House.target.shape)

# %%
#House.feature_names

# %%
import pandas as pd

House_df = pd.DataFrame(House.data,
                             columns=House.feature_names)
House_df.head(10)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6  3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7  3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8  2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9  3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
# 5    -122.25
# 6    -122.25
# 7    -122.25
# 8    -122.26
# 9    -122.25

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#House_df.info()

# %%
#midInc is skwed
#sns.scatterplot(x=House_df['MedInc'],y=House_df['MedHouseValue'])

# %%
#sns.scatterplot(x=House_df['HouseAge'],y=House_df['MedHouseValue'],s=House_df['MedHouseValue']*10) 
#to be normalized

# %%
#sns.scatterplot(House_df['AveRooms']) 
#Normal data

# %%
#sns.scatterplot(House_df['AveBedrms'])

# %%
#sns.scatterplot(House_df['Population'])

# %%
#sns.scatterplot(House_df['AveOccup'])

# %%
sns.scatterplot(x=House_df['Longitude'], y=House_df['Latitude'],
               s=House_df['Population']/50)
# Out:
# <Axes: xlabel='Longitude', ylabel='Latitude'>

# %%
House_df['MedHouseValue']= pd.Series(House.target)

# %%
House_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseValue
# 0    -122.23          4.526
# 1    -122.22          3.585
# 2    -122.24          3.521
# 3    -122.25          3.413
# 4    -122.25          3.422

# %%
House_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude  MedHouseValue
# count  20640.000000  20640.000000  20640.000000   20640.000000
# mean       3.070655     35.631861   -119.569704       2.068558
# std       10.386050      2.135952      2.003532       1.153956
# min        0.692308     32.540000   -124.350000       0.149990
# 25%        2.429741     33.930000   -121.800000       1.196000
# 50%        2.818116     34.260000   -118.490000       1.797000
# 75%        3.282261     37.710000   -118.010000       2.647250
# max     1243.333333     41.950000   -114.310000       5.000010

# %%
corr=House_df.corr()

# %%
Correlation_MHV=corr['MedHouseValue']
Correlation_MHV
# Out:
# MedInc           0.688075
# HouseAge         0.105623
# AveRooms         0.151948
# AveBedrms       -0.046701
# Population      -0.024650
# AveOccup        -0.023737
# Latitude        -0.144160
# Longitude       -0.045967
# MedHouseValue    1.000000
# Name: MedHouseValue, dtype: float64

# %%
Correlation_MHV.plot.bar(x='MedHouseValue')
# Out:
# <Axes: >

# %%
#House_df=House_df.drop(['HouseAge','AveRooms','AveBedrms','Latitude'], axis=1)

# %%
House_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseValue
# 0    -122.23          4.526
# 1    -122.22          3.585
# 2    -122.24          3.521
# 3    -122.25          3.413
# 4    -122.25          3.422

# %%
House_df.hist(bins=50, figsize=(15,10))
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>,
#         <Axes: title={'center': '2'}>],
#        [<Axes: title={'center': '3'}>, <Axes: title={'center': '4'}>,
#         <Axes: title={'center': '5'}>],
#        [<Axes: title={'center': '6'}>, <Axes: title={'center': '7'}>,
#         <Axes: title={'center': '8'}>]], dtype=object)

# %%
import numpy as np
House_df['AveRooms']=np.log(X_train['AveRooms']+1)
House_df['AveBedrms']=np.log(X_train['AveBedrms']+1)
House_df['Population']=np.log(X_train['Population']+1)
House_df['AveOccup']=np.log(X_train['AveOccup']+1)
House_df['MedInc']=np.log(X_train['MedInc']+1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
model=scaler.fit(House_df)
scaled_data=model.transform(House_df)
House_df=pd.DataFrame(scaled_data)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test= train_test_split(House_df.drop(["MedHouseValue"], axis=1),
                                               House.target, random_state=11)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (15480, 8)
# (5160, 8)

# %%
X_train.hist(bins=50, figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'MedInc'}>,
#         <Axes: title={'center': 'HouseAge'}>,
#         <Axes: title={'center': 'AveRooms'}>],
#        [<Axes: title={'center': 'AveBedrms'}>,
#         <Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'AveOccup'}>],
#        [<Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Longitude'}>, <Axes: >]], dtype=object)

# %%
from sklearn.linear_model import LinearRegression
linear_regression=LinearRegression()
linear_regression.fit(X=X_train,y=y_train)

for i,name in enumerate(House.feature_names):
     print(f'{name:>10}: {linear_regression.coef_[i]}')
# Out:
#     MedInc: 5.405500234093443
#   HouseAge: 0.5779969178123472
#   AveRooms: -2.7076178823743398
#  AveBedrms: 3.939303573248073
# Population: 0.2584137901492713
#   AveOccup: -4.437874885603211
#   Latitude: -3.8061395744678226
#  Longitude: -4.0260213293179925

# %%
#sns.scatterplot(x=House_df['MedInc'],y=House_df['MedHouseValue'])
#sns.scatterplot(x=House_df['HouseAge'],y=House_df['MedHouseValue'])
#sns.scatterplot(x=House_df['Population'],y=House_df['MedHouseValue'])
#sns.scatterplot(x=House_df['AveOccup'],y=House_df['MedHouseValue'])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=[]
for i in range(X_train.shape[1]):
    vif.append(variance_inflation_factor(X_train,i))

# %%
#pd.DataFrame({'vif':vif}, index=House_df.columns[0:8]).T

# %%
#sns.heatmap(House_df.iloc[:,0:8].corr(),annot=True)

# %%
print(linear_regression.intercept_)
# Out:
# 3.852856251087456

# %%
predicted = linear_regression.predict(X_test)
expected = y_test

# %%
df = pd.DataFrame()
df['Expected'] = pd.Series(expected)
df['Predicted'] = pd.Series(predicted)
figure = plt.figure(figsize=(9, 9))
sns.scatterplot(data=df, x='Expected', y='Predicted',hue='Predicted')
# Out:
# <Axes: xlabel='Expected', ylabel='Predicted'>

# %%
start= min(expected.min(), predicted.min())
end = max(expected.max(), predicted.max())

line = plt.plot([start, end], [start, end], '--')

# %%
from sklearn import metrics
print(f'The R2 score: {metrics.r2_score(expected, predicted)}\n')
print(f'The MSE: {metrics.mean_squared_error(expected, predicted)}')
# Out:
# The R2 score: -447693.1086635176
#
# The MSE: 600155.4501233504

# %%
residue= predicted-expected

# %%
sns.distplot(residue)
# Out:
# C:\Users\atharva.sharma\AppData\Local\Temp\ipykernel_7056\102571781.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residue)
# <Axes: ylabel='Density'>

# %%
import scipy as sp
fig, ax = plt.subplots(figsize=(6,4))
sp.stats.probplot(residue, plot=ax, fit=True)
plt.show()
#errors are not normally distributed

# %%
plt.scatter(predicted,residue)

# %%
plt.plot(residue)

# %%
X_train
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0      0.743162  0.803922  0.527198   0.284545    0.761029  0.281769
# 1      0.527731  0.823529  0.527859   0.293146    0.796776  0.343824
# 2      0.128865  0.098039  0.457520   0.278445    0.790520  0.364810
# 3      0.759281  0.411765  0.578511   0.293311    0.821334  0.310022
# 4      0.313627  1.000000  0.456096   0.303242    0.773925  0.291384
# ...         ...       ...       ...        ...         ...       ...
# 15475  0.392969  0.294118  0.417504   0.293985    0.899212  0.456842
# 15476  0.478287  0.882353  0.514776   0.313374    0.815039  0.325509
# 15477  0.390462  0.686275  0.445269   0.287916    0.845865  0.413658
# 15478  0.524187  0.254902  0.473015   0.322985    0.739103  0.341263
# 15479  0.485372  0.627451  0.526163   0.279620    0.766247  0.294498
#
#        Latitude  Longitude
# 0      0.170032   0.594622
# 1      0.167906   0.625498
# 2      0.387885   0.498008
# 3      0.642933   0.299801
# 4      0.578108   0.394422
# ...         ...        ...
# 15475  0.509033   0.249004
# 15476  0.174283   0.580677
# 15477  0.156217   0.615538
# 15478  0.172157   0.591633
# 15479  0.145590   0.643426
#
# [15480 rows x 8 columns]

# %%
X_train.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'MedInc'}>,
#         <Axes: title={'center': 'HouseAge'}>,
#         <Axes: title={'center': 'AveRooms'}>],
#        [<Axes: title={'center': 'AveBedrms'}>,
#         <Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'AveOccup'}>],
#        [<Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Longitude'}>, <Axes: >]], dtype=object)
